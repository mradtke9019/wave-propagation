# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(-np.pi, np.pi, 512)
C, S = np.cos(X), np.sin(X)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-2,-1, 0, +1,+2],
          [r'$-2$',r'$-1$', r'$0$', r'$+1$',r'$+2$'])

Sum = C + S
plt.plot(X, C)
plt.plot(X, S)
plt.plot(X, Sum)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="sine")
plt.plot(X, Sum, color="purple",  linewidth=2.5, linestyle="-", label="Sum")

plt.legend(loc='upper left')

ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.show()

# %%
class WaveSource:
    def __init__(self, x, y):
        self.x = x
        self.y = y
class WaveIteration:
    def __init__(self, time, r_hi, r_lo, x_hi, x_lo, y_hi, y_lo, amplitude):
        self.time = time
        self.r_hi = r_hi
        self.r_lo = r_lo

        self.x_hi = x_hi
        self.y_hi = y_hi

        self.x_lo = x_lo
        self.y_lo = y_lo
        self.amplitude = amplitude

# %%
def share_point(xList1, xList2, yList1, yList2):
    error = 0.01
    i = 0
    for i in range(len(xList1)):
        x1 = xList1[i]
        y1 = yList1[i]
        for j in range(len(xList2)):
            x2 = xList2[j]
            y2 = yList2[j]
            if (x1 == x2 and y1 == y2) or (abs(x1 - x2) <= error and abs(y1 - y2) <= error):
                return True
    return False

    for i in range(len(xList1)):
        x1 = xList1[i]
        x2 = xList2[i]
        #print("comparing x1 at " + str(i) + " against x2 at " + str(j))
        #print(str(x1) + " =? " + str(x2))
        if x1 == x2 or abs(x1 - x2 <= error):
            # we have equal x's, check if the y is also the same
            if yList1[i] == yList2[i] or abs(yList1[i] - yList2[i]) <= error:
                return True
    return False

# %%
# Test our share point data
x1s = [1,2,3,4,5]
y1s = [2,2,3.0001,4,5]

x2s = [1,1,3,1,1]
y2s = [1,1,3,1,1]

print(share_point(x1s,x2s,y1s,y2s))
# Out:
# True

# %%
# Code below used by Lecture 1 from Professor Fergal Shevlin, modified to hopefully demonstrate wave propagation

fig = plt.figure()
ax = plt.gca()

#-- Set axis spines at 0
for spine in ['left', 'bottom']:
    ax.spines[spine].set_position('zero')

#-- Hide the other spines...
for spine in ['right', 'top']:
    ax.spines[spine].set_color('none')

#-- Decorate the spines
arrow_length = 20 # In points

#-- X-axis arrow
ax.annotate('$x$', xy=(1, 0), xycoords=('axes fraction', 'data'), 
            xytext=(arrow_length, 0), textcoords='offset points',
            ha='left', va='center',
            arrowprops=dict(arrowstyle='<|-', fc='black'))

#-- Y-axis arrow
ax.annotate('$y$', xy=(0, 1), xycoords=('data', 'axes fraction'), 
            xytext=(0, arrow_length), textcoords='offset points',
            ha='center', va='bottom',
            arrowprops=dict(arrowstyle='<|-', fc='black'))

#-- Plot
ax.axis([-5.25*np.pi/2, 7.6*np.pi, -1.6*np.pi, 3.6*np.pi])
ax.grid(False)
ax.set_aspect(1)


# Turn off ticks
ax.set_yticks([])
ax.set_xticks([])

# Turn off tick labels
ax.set_yticklabels([])
ax.set_xticklabels([])


# Create origins each 2 pi apart
wave_data = {}
origin_count = 5
wave_sources = []
for i in np.linspace(0, origin_count * 2*np.pi, origin_count):
    wave_sources.append(WaveSource(x=i, y=0))
waveSteps = 5
slices = 100

for source in wave_sources:
    wave_data[source] = []
    for time in range(waveSteps):
        # create our theta from 0 to 360 degrees into slices
        theta = np.linspace(0, 2*np.pi, slices)

        r_hi = time*2*np.pi - (3*np.pi/2)
        r_lo = time*2*np.pi - (np.pi/2)

        x_hi = r_hi*np.cos(theta)
        y_hi = r_hi*np.sin(theta)

        x_lo = r_lo*np.cos(theta)
        y_lo = r_lo*np.sin(theta)
        
        # offset by the origin of our wave sources
        x_hi = x_hi + source.x
        y_hi = y_hi + source.y
        
        x_lo = x_lo + source.x
        y_lo = y_lo + source.y
        #wave_data[source][str(time)] = WaveIteration(time,r_hi, r_lo, x_hi, x_lo, y_hi, y_lo)
        wave_data[source].append(WaveIteration(time,r_hi, r_lo, x_hi, x_lo, y_hi, y_lo, 0.1))
        if time==2: 
            ax.plot(x_hi, y_hi, 'k-', linewidth=2 ,color=(wave_data[source][time].amplitude, 0.0, 0.0))
            ax.plot(x_lo, y_lo, 'k--', linewidth=2, color=(wave_data[source][time].amplitude, 0.0, 0.0))
        else:
            ax.plot(x_hi, y_hi, 'k-', linewidth=1, color=(wave_data[source][time].amplitude, 0.0, 0.0))
            ax.plot(x_lo, y_lo, 'k--', linewidth=1, color=(wave_data[source][time].amplitude, 0.0, 0.0))

for time in range(waveSteps):
    # find if there are any waves that share the same position for the current time and
    # increase their amplitude at that point
    for source in wave_sources:
        curr = wave_data[source][time]
        for source2 in wave_sources:
            if(source2 == source):
                continue
            compared = wave_data[source2][time]
            if(curr.time != compared.time):
                continue
            # now we guarantee the waves are at the same point in time, do they intersect?
            sharedpoints= share_point(curr.x_lo, compared.x_lo, curr.y_lo, compared.y_lo) or share_point(curr.x_hi, compared.x_hi, curr.y_hi, compared.y_hi)
            # print("Share point at time " + str(time) + "? " + str(sharedpoints))

# for source in wave_sources:
#     print(wave_data[source])
#     for time in range(len(data)):
#         if time==2: 
#             ax.plot(wave_data[data][time].x_hi, wave_data[data][time].y_hi, 'k-', linewidth=2 ,color=(wave_data[data][time].amplitude, 0.0, 0.0))
#             ax.plot(wave_data[data][time].x_lo, wave_data[data][time].y_lo, 'k--', linewidth=2, color=(wave_data[data][time].amplitude, 0.0, 0.0))
#         else:
#             ax.plot(wave_data[data][time].x_hi, wave_data[data][time].y_hi, 'k-', linewidth=1, color=(wave_data[data][time].amplitude, 0.0, 0.0))
#             ax.plot(wave_data[data][time].x_lo, wave_data[data][time].y_lo, 'k--', linewidth=1, color=(wave_data[data][time].amplitude, 0.0, 0.0))
# plt.show()
